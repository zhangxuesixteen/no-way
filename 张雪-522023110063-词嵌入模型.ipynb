#
#                                                 广告文本分词
# 0    兰勃 脱白 脱勒 公司   五华 牌 香烟   佛及 尼埃 香烟     二十 枝装 每包 ...
# 1    讲求 卫生 为 人生 本性 天理 固然 也   人生 首贵 逐日 大便 通畅 有序 为 天然...
# 2                          香味 馥郁 , 不让 名花   另 有 三 炮台 出售
# 3    差肩 儿女   秀慧 康强   闽有 佳音 讃 羡 婴孩 自己 药片   每年 此际 小儿 ...
# 4    何以 亚士 北罗 是 妇女 们 的 腻友 ？ 各国 妇女 力证 亚士 北罗 药片 是 她们 ...
# ..                                                 ...
# 495  安住 蚊烟香   臭虫 立毙 药粉   世界 第一名 产   安住 蚊烟香   蚊见 逃 慌...
# 496  眉色 清秀   气色 壮旺   此 第 威德 润肠 丸 之功 也   第 威德 润肠 丸系 ...
# 497  汤火 烫伤   立 攃 如意 膏 可免 严重 之 后果   皮肤 受伤 当以 灼烫 最 痛苦...
# 498  清血 解毒 六零 六   花柳 梅毒 瘰 * 疮 疖 癣疥 * * 及 筋骨 酸痛 四肢 麻...
# 499  三 炮台 香烟 , ' 到底 是 好   三 炮台   好 香烟   敬 宾客   美 观瞻...
#
# [500 rows x 7 columns]

# %% [markdown]
# # 词向量模型

# %% [markdown]
# 词向量（Word Vectors）是将词语映射到向量空间，使其成为向量空间中的一个点。在这个空间中，语义上相似的单词在空间中的距离也相近。在这个向量空间中，每个词语都用一个向量表示，这个向量是多维的，并且每一维都是一个实数。这就是所谓“单个词语的词向量”。

# %% [markdown]
# 使用词向量，我们可以进行各种文本分析任务，如文本分类、情感分析、文本相似度计算等。通过计算两个词向量之间的余弦相似度，我们可以得到这两个词语在语义上的相似度。

# %%
from gensim.test.utils import common_texts
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
corpus = df['广告文本分词'].apply(lambda x: x.split()).tolist() # 切分词语
for document in corpus[:5]:
    print(document)
# Out:
# ['兰勃', '脱白', '脱勒', '公司', '五华', '牌', '香烟', '佛及', '尼埃', '香烟', '二十', '枝装', '每包', '售', '国币', '大洋', '二角', '五十', '枝装', '每罐', '售', '国币', '大洋', '五角']
# ['讲求', '卫生', '为', '人生', '本性', '天理', '固然', '也', '人生', '首贵', '逐日', '大便', '通畅', '有序', '为', '天然', '所当', '如此', '也', '如若', '大便', '不利', '大', '肠阻塞', '则', '胃失', '消化', '疾病', '头痛', '肝火', '上升', '胆汁', '不', '调', '口气', '积浊', '舌现', '黄苔', '诸恙', '接踵', '而', '起', '矣', '凡', '此皆须', '服用', '韦廉士', '大', '医生', '红色', '清导丸', '以利', '大便', '俾得', '体质', '强健', '百病', '不侵', '也况', '此丸', '之', '功力', '天然', '平和', '不尚', '霸烈', '广东省', '城', '医生', '学', '研究会', '*', '
', '他', '的', '安适', '和', '快乐', '亚士', '北罗', '药片', '才', '是', '他们', '最', '亲爱', '的', '腻友', '比', '爱人', '更', '爱慕', '故此', '妇女', '们', '对亚士', '北罗', '药片', '万分', '的', '信任', '和', '欢迎', '婚后', '！', '女子', '结了婚', '她', '的', '唯一', '责任', '就是', '养育', '儿女', '照料', '丈夫', '想尽', '两种', '责任', '她', '的', '唯一', '信赖', '就是', '亚士', '北罗', '药片', '遇着', '丈夫', '和', '儿女', '发生', '疾病', '的', '时候', '如', '头痛', '肚痛', '感冒', '伤风', '风湿', '发热', '使', '她', '的', '芳心', '最感', '不安', '用', '了', '亚士', '北罗', '药片', '丈夫', '和', '儿女', '也', '得到', '平安', '可以', '使', '她', '安乐', '无忧', '因为', '丈夫', '出外', '工作', '最易', '伤风感冒', '工作', '过劳', '神经病', '或', '头痛', '儿女', '最易', '伤风感冒', '发热', '牙痛', '肚痛', '亚士', '北罗', '药片', '可立止', '葛', '总', '病症', '退热', '愈风', '疾故', '婚后', '妇女', '们', '视亚士', '北罗', '药片', '比', '丈夫', '和', '儿女', '更', '重要', '备有', '亚士', '北罗', '药片', '便', '可', '使', '全家', '平安', '一', '五分钟', '至', '十分钟', '立止', '剧烈', '头痛', '二', '能', '使', '失眠', '者', '得', '安乐', '睡眠', '三', '能', '驱除', '各种', '痛症', '五', '能治', '牙痛', '驱除', '牙患', '六', '提神', '却病', '助消化', '七', '立止', '各种', '痛症', '无害', '于', '此', '八', '治', '腹部', '肠', '刺痛', '九', '以热', '柠檬汁', '溶和亚士', '北罗', '药片', '两三片', '饮服', '立可', '驱除', '伤风感冒', '十', '五分钟', '至', '十分钟', '立即', '退热', '十一', '无论', '在', '舟车', '家庭', '随时随地', '可以', '服用', '十二', '专治', '妇女', '忧虑', '过步', '十三', '能', '醒酒', '提神', '十四', '善治', '大肠', '热及', '退', '各种', '热症', '十五', '用亚士', '北罗', '药片', '治喉', '痛', '是', '最', '安全', '之', '法', '小盒', '三毫', '中盒', '六毫', '大盒', '一元', '半', '广州', '沙面', '天祥', '洋行', '总经理', '各大', '药房', '均', '有', '代售', 'ASPRO']

# %%
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    epochs = 10
)

# 保存训练好的模型
model.save('word2vec_ad.model')

# %%
word_list = model.wv.index_to_key  # 获取词汇表
word_vectors = model.wv[word_list]  # 获取词向量

# 打印词汇表和对应的词向量
for word, vector in list(zip(word_list, word_vectors))[:5]:
    print(f'{word}: {vector}')
# Out:
# 之: [-0.6410849   1.134391    0.63549495 -0.38521895 -0.48411548 -2.2945507
#   0.83481675  3.1726503  -1.3157034  -1.3893381  -0.3336429  -1.8243196
#  -0.18684328  1.2022493   0.598506   -0.7134296   0.3007021  -0.5595516
#   0.8671313  -0.12991086  1.8000575   1.2405846  -0.11303473  0.51230925
#  -0.6989241   0.34625518 -0.7115636  -1.4093369  -0.8603346   1.622855
#  -1.7644452  -0.8499487   0.7066167   1.328604   -0.66366124  1.330998
#   1.9615377   0.56771076 -0.35473382  1.0636941   2.7316723   0.5649288
#  -0.52594763  0.37304056 -0.16403672 -0.47331512]

# %%
# 检查词嵌入模型中任意两个词向量的余弦相似度，即语义接近性
# 余弦相似度的取值介于[-1, 1]之间，-1表示语义完全相反，1表示语义完全相同，0表示毫无关系
# model.sv.similarity这个函数与np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))的输出结果一致
print(model.wv.similarity('医生', '疼痛'))
print(model.wv.similarity('医生', '神经'))
print(model.wv.similarity('医生', '伤风'))
print(model.wv.similarity('疼痛', '神经'))
print(model.wv.similarity('疼痛', '伤风'))
print(model.wv.similarity('神经', '伤风'))
# Out:
# -0.36037835
# -0.104999244
# 0.111444846
# 0.73615587
# 0.56135345
# 0.56218207

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA #用于降维处理
import matplotlib

# 可视化

words = ['医生', '疼痛', '神经', '伤风']
vectors = [model.wv[word] for word in words]

from matplotlib.font_manager import FontProperties
font_path = '/System/Library/Fonts/PingFang.ttc' 
custom_font = FontProperties(fname=font_path, size=14)

matplotlib.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# 使用PCA进行降维
pca = PCA(n_components = 2)
pca_result = pca.fit_transform(vectors)

plt.figure()

# 取PCA降维结果中所有行的第一列和第二列数据绘制散点图，设置点的大小为50
plt.scatter(pca_result[:, 0], pca_result[:, 1], s = 50)

for i, word in enumerate(words):
    plt.annotate(word, (pca_result[i, 0], pca_result[i, 1]), fontsize = 20)

plt.xlabel('PCA维度1', fontsize = 20)
plt.ylabel('PCA维度2', fontsize = 20)
plt.title('二维语义空间中词语的分布', fontsize = 20)
plt.grid(True)
plt.show()

# %%
from gensim.models.callbacks import CallbackAny2Vec

class callback(CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 0
        self.loss_to_be_subed = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        loss_now = loss - self.loss_to_be_subed
        self.loss_to_be_subed = loss
        print('Loss after epoch {}: {}'.format(self.epoch, loss_now))
        self.epoch += 1
        
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    compute_loss=True, callbacks=[callback()],
    epochs = 50
)

# 保存训练好的模型
model.save('word2vec_ad.model')
# Out:
# Loss after epoch 0: 78569.96875
# Loss after epoch 1: 69607.453125
# Loss after epoch 2: 73491.0
# Loss after epoch 3: 54889.578125
# Loss after epoch 4: 55280.875
# Loss after epoch 5: 51656.84375
# Loss after epoch 6: 49559.21875
# Loss after epoch 7: 47889.46875
# Loss after epoch 8: 46272.65625
# Loss after epoch 9: 44818.5
# Loss after epoch 10: 43563.9375
# Loss after epoch 11: 37814.9375
# Loss after epoch 12: 40878.625
# Loss after epoch 13: 39939.5
# Loss after epoch 14: 34705.8125
# Loss after epoch 15: 33448.3125
# Loss after epoch 16: 36230.3125
# Loss after epoch 17: 31836.0
# Loss after epoch 18: 30850.5625
# Loss after epoch 19: 33432.0625
# Loss after epoch 20: 29443.6875
# Loss after epoch 21: 31779.5625
# Loss after epoch 22: 31052.8125
# Loss after epoch 23: 30457.4375
# Loss after epoch 24: 29591.25
# Loss after epoch 25: 28839.875
# Loss after epoch 26: 28106.0
# Loss after epoch 27: 24942.25
# Loss after epoch 28: 27006.875
# Loss after epoch 29: 26652.125
# Loss after epoch 30: 26334.375
# Loss after epoch 31: 25697.625
# Loss after epoch 32: 25571.625
# Loss after epoch 33: 25006.875
# Loss after epoch 34: 24675.375
# Loss after epoch 35: 21934.875
# Loss after epoch 36: 21679.625
# Loss after epoch 37: 23739.125
# Loss after epoch 38: 23444.875
# Loss after epoch 39: 23085.875
# Loss after epoch 40: 23065.125
# Loss after epoch 41: 22779.375
# Loss after epoch 42: 22569.875
# Loss after epoch 43: 22505.375
# Loss after epoch 44: 22484.75
# Loss after epoch 45: 22224.625
# Loss after epoch 46: 22085.125
# Loss after epoch 47: 20021.75
# Loss after epoch 48: 22062.375
# Loss after epoch 49: 19821.625

# %% [markdown]
# # 二、词嵌入模型1——铁路与殖民统治

# %%
pip install pandas nltk
# Out:
# Requirement already satisfied: pandas in /Users/sharon/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: nltk in /Users/sharon/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: click in /Users/sharon/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/sharon/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/sharon/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: six>=1.5 in /Users/sharon/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd # 数据表
df = pd.read_excel('railway_construction_AND_colonial_power.xlsx', header=0)
df
# Out:
#                                                  title  \
# 0                                       Anticorruption
# 1    Exploring the Social Life of Japanese" Manchur...
# 2    Comparative media history: An introduction: 17...
# 3    British Imperialism and Decolonization: a Chin...
# 4    Skilled labour in colonial economies. Recruitm...
# ..                                                 ...
# 995  Colonial Kenya observed: British rule, Mau Mau...
# 996  History of Sub-Saharan Africa's Long Journey t...
# 997  Great power politics in the fourth industrial ...
# 998          The plural economy and its legacy in Asia
# 999                                              Libya
#
#                                                   href  year
# 0    https://books.google.com/books?hl=zh-CN&lr=&id...  2020
# 1    https://link.springer.com/content/pdf/10.1007/...  2020
# 2    https://books.google.com/books?hl=zh-CN&lr=&id...  2005
# 3    https://link.springer.com/chapter/10.1057/9781...  2002
# 4    https://www.tandfonline.com/doi/abs/10.1080/00...  2022
# ..                                                 ...   ...
# 995  https://books.google.com/books?hl=zh-CN&lr=&id...  2014
# 996  https://brill.com/view/journals/bafr/15/4/arti...  2023
# 997                                                NaN  2022
# 998  https://library.oapen.org/bitstream/handle/20....  2012
# 999  https://link.springer.com/chapter/10.1007/978-...  2019
#
# [1000 rows x 3 columns]

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) #去除英文停用词

def preprocess_text(text):
    text = text.lower() #小写
    text = re.sub(r'\d+', '', text) #删除数字
    text = re.sub(r'[^\w\s]', '', text) #删除标点符号
    words = text.split() #用空格分割
    words = [word for word in words if word not in stop_words and re.match(r'[a-zA-Z]+', word)]  # 去除停用词和非字母单词
    text = ' '.join(words)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sharon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['title'] = df['title'].astype(str) #将对象转化为字符串类型
df['title_new'] = df['title'].apply(preprocess_text) #执行清洗操作
df.head()
# Out:
#                                                title  \
# 0                                     Anticorruption
# 1  Exploring the Social Life of Japanese" Manchur...
# 2  Comparative media history: An introduction: 17...
# 3  British Imperialism and Decolonization: a Chin...
# 4  Skilled labour in colonial economies. Recruitm...
#
#                                                 href  year  \
# 0  https://books.google.com/books?hl=zh-CN&lr=&id...  2020
# 1  https://link.springer.com/content/pdf/10.1007/...  2020
# 2  https://books.google.com/books?hl=zh-CN&lr=&id...  2005
# 3  https://link.springer.com/chapter/10.1057/9781...  2002
# 4  https://www.tandfonline.com/doi/abs/10.1080/00...  2022
#
#                                            title_new
# 0                                     anticorruption
# 1  exploring social life japanese manchurian immi...
# 2     comparative media history introduction present
# 3  british imperialism decolonization chinese per...
# 4  skilled labour colonial economies recruitment ...

# %%
text_column = 'title_new'

# %% [markdown]
# ## 分词

# %%
from nltk.tokenize import word_tokenize
import nltk

# 确保已经下载了nltk的tokenizers
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/sharon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# 定义一个分词函数
def tokenize_text(text):
    # 确保文本是字符串类型
    if not isinstance(text, str):
        text = str(text)  # 转换非字符串类型为字符串
    # 使用nltk进行分词
    return word_tokenize(text)

# 应用分词函数到指定列
df[text_column + '_tokens'] = df[text_column].apply(tokenize_text)
df
# Out:
#                                                  title  \
# 0                                       Anticorruption
# 1    Exploring the Social Life of Japanese" Manchur...
# 2    Comparative media history: An introduction: 17...
# 3    British Imperialism and Decolonization: a Chin...
# 4    Skilled labour in colonial economies. Recruitm...
# ..                                                 ...
# 995  Colonial Kenya observed: British rule, Mau Mau...
# 996  History of Sub-Saharan Africa's Long Journey t...
# 997  Great power politics in the fourth industrial ...
# 998          The plural economy and its legacy in Asia
# 999                                              Libya
#
#                                                   href  year  \
# 0    https://books.google.com/books?hl=zh-CN&lr=&id...  2020
# 1    https://link.springer.com/content/pdf/10.1007/...  2020
# 2    https://books.google.com/books?hl=zh-CN&lr=&id...  2005
# 3    https://link.springer.com/chapter/10.1057/9781...  2002
# 4    https://www.tandfonline.com/doi/abs/10.1080/00...  2022
# ..                                                 ...   ...
# 995  https://books.google.com/books?hl=zh-CN&lr=&id...  2014
# 996  https://brill.com/view/journals/bafr/15/4/arti...  2023
# 997                                                NaN  2022
# 998  https://library.oapen.org/bitstream/handle/20....  2012
# 999  https://link.springer.com/chapter/10.1007/978-...  2019
#
#                                              title_new  \
# 0                                       anticorruption
# 1    exploring social life japanese manchurian immi...
# 2       comparative media history introduction present
# 3    british imperialism decolonization chinese per...
# 4    skilled labour colonial economies recruitment ...
# ..                                                 ...
# 995  colonial kenya observed british rule mau mau w...
# 996  history subsaharan africas long journey toward...
# 997  great power politics fourth industrial revolut...
# 998                         plural economy legacy asia
# 999                                              libya
#
#                                       title_new_tokens
# 0                                     [anticorruption]
# 1    [exploring, social, life, japanese, manchurian...
# 2    [comparative, media, history, introduction, pr...
# 3    [british, imperialism, decolonization, chinese...
# 4    [skilled, labour, colonial, economies, recruit...
# ..                                                 ...
# 995  [colonial, kenya, observed, british, rule, mau...
# 996  [history, subsaharan, africas, long, journey, ...
# 997  [great, power, politics, fourth, industrial, r...
# 998                    [plural, economy, legacy, asia]
# 999                                            [libya]
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 词向量模型

# %%
from gensim.test.utils import common_texts
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
corpus = df['title_new_tokens']
for document in corpus[:5]:
    print(document)
# Out:
# ['anticorruption']
# ['exploring', 'social', 'life', 'japanese', 'manchurian', 'immigrants']
# ['comparative', 'media', 'history', 'introduction', 'present']
# ['british', 'imperialism', 'decolonization', 'chinese', 'perspective']
# ['skilled', 'labour', 'colonial', 'economies', 'recruitment', 'education', 'employment', 'construction', 'companies', 'german', 'colonial', 'west', 'africa', 'c']

# %%
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    epochs = 10
)

# 保存训练好的模型
model.save('word2vec_ad.model')

# %%
word_list = model.wv.index_to_key  # 获取词汇表
word_vectors = model.wv[word_list]  # 获取词向量

# 打印词汇表和对应的词向量
for word, vector in list(zip(word_list, word_vectors))[:5]:
    print(f'{word}: {vector}')
# Out:
# colonial: [-0.01604662  0.03089988  0.01056053  0.01529846 -0.00837597 -0.05215831
#   0.02734143  0.0677591  -0.02594678 -0.02102994 -0.0072899  -0.05590078
#  -0.00973533  0.02231069  0.00808039 -0.03051955  0.00631827 -0.0361956
#  -0.00904821 -0.05486099  0.03361551  0.01872972  0.02254272 -0.00790237
#   0.00556434 -0.00193038 -0.02367    -0.0142752  -0.03730204 -0.00410459
#   0.02297763  0.00966691  0.01527065 -0.03555943 -0.01429212  0.02490919
#   0.01700739 -0.02265775 -0.02141104 -0.05330011 -0.00617146 -0.0142512
#  -0.0193376  -0.00593042  0.02582088 -0.01341827 -0.03027898 -0.00162045
#   0.01889614  0.03247089  0.00044139 -0.01367296 -0.01642617 -0.01261732
#  -0.00781759  0.00817854  0.02411555 -0.01974921 -0.03354779  0.01488409
#   0.0037633   0.00681879 -0.01087907 -0.00371732 -0.04155154  0.02120936
#  -0.00455893  0.0184495  -0.0405026   0.03657033 -0.00731732  0.02255348
#   0.02933441 -0.0153482   0.03938451  0.01904536  0.0156209  -0.00630317
#  -0.0110475  -0.00920489  0.01316471  0.01206293  0.00598033  0.00116195
#   0.02343344  0.00305004  0.01053332  0.00052501  0.02547899  0.00229468
#   0.01464355 -0.00792266  0.0029728   0.00348589]

# %%
print(model.wv.similarity('exploring', 'decolonization'))
print(model.wv.similarity('exploring', 'recruitment'))
print(model.wv.similarity('exploring', 'comparative'))
print(model.wv.similarity('decolonization', 'recruitment'))
print(model.wv.similarity('decolonization', 'comparative'))
print(model.wv.similarity('recruitment', 'comparative'))
# Out:
# 0.07072468
# 0.16657437
# 0.09472793
# 0.119863845
# 0.094864994
# 0.27576584

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA #用于降维处理
import matplotlib

# 可视化

words = ['exploring', 'decolonization', 'recruitment', 'comparative']
vectors = [model.wv[word] for word in words]

from matplotlib.font_manager import FontProperties
font_path = '/System/Library/Fonts/PingFang.ttc' 
custom_font = FontProperties(fname=font_path, size=14)

matplotlib.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# 使用PCA进行降维
pca = PCA(n_components = 2)
pca_result = pca.fit_transform(vectors)

plt.figure()

# 取PCA降维结果中所有行的第一列和第二列数据绘制散点图，设置点的大小为50
plt.scatter(pca_result[:, 0], pca_result[:, 1], s = 50)

for i, word in enumerate(words):
    plt.annotate(word, (pca_result[i, 0], pca_result[i, 1]), fontsize = 20)

plt.xlabel('PCA维度1', fontsize = 20)
plt.ylabel('PCA维度2', fontsize = 20)
plt.title('二维语义空间中词语的分布', fontsize = 20)
plt.grid(True)
plt.show()

# %%
from gensim.models.callbacks import CallbackAny2Vec

class callback(CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 0
        self.loss_to_be_subed = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        loss_now = loss - self.loss_to_be_subed
        self.loss_to_be_subed = loss
        print('Loss after epoch {}: {}'.format(self.epoch, loss_now))
        self.epoch += 1
        
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    compute_loss=True, callbacks=[callback()],
    epochs = 50
)

# 保存训练好的模型
model.save('word2vec_ad.model')
# Out:
# Loss after epoch 0: 27448.21875
# Loss after epoch 1: 27632.06640625
# Loss after epoch 2: 27405.64453125
# Loss after epoch 3: 27529.3203125
# Loss after epoch 4: 27301.53125
# Loss after epoch 5: 27378.328125
# Loss after epoch 6: 27642.25
# Loss after epoch 7: 27423.828125
# Loss after epoch 8: 27423.890625
# Loss after epoch 9: 27067.921875
# Loss after epoch 10: 26898.90625
# Loss after epoch 11: 26088.53125
# Loss after epoch 12: 25370.96875
# Loss after epoch 13: 24499.03125
# Loss after epoch 14: 23915.5
# Loss after epoch 15: 23099.0
# Loss after epoch 16: 22500.0625
# Loss after epoch 17: 21772.40625
# Loss after epoch 18: 21291.5625
# Loss after epoch 19: 20980.1875
# Loss after epoch 20: 20556.46875
# Loss after epoch 21: 20397.875
# Loss after epoch 22: 19966.5
# Loss after epoch 23: 19745.5
# Loss after epoch 24: 19525.5
# Loss after epoch 25: 19463.0625
# Loss after epoch 26: 19425.0625
# Loss after epoch 27: 19279.5
# Loss after epoch 28: 19170.25
# Loss after epoch 29: 19121.6875
# Loss after epoch 30: 19042.0625
# Loss after epoch 31: 19045.0625
# Loss after epoch 32: 19011.1875
# Loss after epoch 33: 18998.875
# Loss after epoch 34: 18853.375
# Loss after epoch 35: 18832.5
# Loss after epoch 36: 18799.875
# Loss after epoch 37: 18705.875
# Loss after epoch 38: 18716.9375
# Loss after epoch 39: 18632.375
# Loss after epoch 40: 18740.5
# Loss after epoch 41: 18687.5625
# Loss after epoch 42: 18729.0
# Loss after epoch 43: 18643.6875
# Loss after epoch 44: 18652.8125
# Loss after epoch 45: 18620.5
# Loss after epoch 46: 18529.8125
# Loss after epoch 47: 18583.8125
# Loss after epoch 48: 18536.125
# Loss after epoch 49: 18579.125

# %% [markdown]
# # 三、词嵌入模型2——铁路与反殖民斗争

# %%
import pandas as pd # 数据表
df = pd.read_excel('colonial_railways_OR_anti-colonial_struggle.xlsx', header=0)
df
# Out:
#                                                  title  \
# 0    Aid in Sino-African Relations: An Analysis of ...
# 1                 Competing Truths in Northern Ireland
# 2                             Protests in 21st Century
# 3    Tracing fragments in the visual culture of ant...
# 4    Cultural accommodation and self-translation in...
# ..                                                 ...
# 994  Love and Revolution in the Twentieth-Century C...
# 995  Nationalism, anti-colonialism and the crystall...
# 996                                 A narchism, I ndia
# 997  The politics of accessing leadership the niger...
# 998  On the Dispensability of New Transportation Te...
#
#                                                   href  year
# 0    https://search.ebscohost.com/login.aspx?direct...  2011
# 1    https://digitalcollections.sit.edu/isp_collect...  2007
# 2    https://heinonline.org/hol-cgi-bin/get_pdf.cgi...  2020
# 3               http://shura.shu.ac.uk/id/eprint/10495  2006
# 4    https://www.torrossa.com/gs/resourceProxy?an=5...    -1
# ..                                                 ...   ...
# 994  https://books.google.com/books?hl=zh-CN&lr=&id...  2021
# 995  https://www.tandfonline.com/doi/abs/10.1080/14...  2013
# 996  https://onlinelibrary.wiley.com/doi/abs/10.100...  2009
# 997  https://dspace.unijos.edu.ng/jspui/bitstream/1...  2013
# 998  https://ruor.uottawa.ca/items/0cebd597-ce36-4f...  2016
#
# [999 rows x 3 columns]

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) #去除英文停用词

def preprocess_text(text):
    text = text.lower() #小写
    text = re.sub(r'\d+', '', text) #删除数字
    text = re.sub(r'[^\w\s]', '', text) #删除标点符号
    words = text.split() #用空格分割
    words = [word for word in words if word not in stop_words and re.match(r'[a-zA-Z]+', word)]  # 去除停用词和非字母单词
    text = ' '.join(words)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sharon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['title'] = df['title'].astype(str) #将对象转化为字符串类型
df['title_new'] = df['title'].apply(preprocess_text) #执行清洗操作
df.head()
# Out:
#                                                title  \
# 0  Aid in Sino-African Relations: An Analysis of ...
# 1               Competing Truths in Northern Ireland
# 2                           Protests in 21st Century
# 3  Tracing fragments in the visual culture of ant...
# 4  Cultural accommodation and self-translation in...
#
#                                                 href  year  \
# 0  https://search.ebscohost.com/login.aspx?direct...  2011
# 1  https://digitalcollections.sit.edu/isp_collect...  2007
# 2  https://heinonline.org/hol-cgi-bin/get_pdf.cgi...  2020
# 3             http://shura.shu.ac.uk/id/eprint/10495  2006
# 4  https://www.torrossa.com/gs/resourceProxy?an=5...    -1
#
#                                            title_new
# 0  aid sinoafrican relations analysis promptings ...
# 1                  competing truths northern ireland
# 2                                protests st century
# 3  tracing fragments visual culture anticolonial ...
# 4  cultural accommodation selftranslation work la...

# %%
text_column = 'title_new'

# %%
from nltk.tokenize import word_tokenize
import nltk

# 确保已经下载了nltk的tokenizers
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/sharon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# 定义一个分词函数
def tokenize_text(text):
    # 确保文本是字符串类型
    if not isinstance(text, str):
        text = str(text)  # 转换非字符串类型为字符串
    # 使用nltk进行分词
    return word_tokenize(text)

# 应用分词函数到指定列
df[text_column + '_tokens'] = df[text_column].apply(tokenize_text)
df
# Out:
#                                                  title  \
# 0    Aid in Sino-African Relations: An Analysis of ...
# 1                 Competing Truths in Northern Ireland
# 2                             Protests in 21st Century
# 3    Tracing fragments in the visual culture of ant...
# 4    Cultural accommodation and self-translation in...
# ..                                                 ...
# 994  Love and Revolution in the Twentieth-Century C...
# 995  Nationalism, anti-colonialism and the crystall...
# 996                                 A narchism, I ndia
# 997  The politics of accessing leadership the niger...
# 998  On the Dispensability of New Transportation Te...
#
#                                                   href  year  \
# 0    https://search.ebscohost.com/login.aspx?direct...  2011
# 1    https://digitalcollections.sit.edu/isp_collect...  2007
# 2    https://heinonline.org/hol-cgi-bin/get_pdf.cgi...  2020
# 3               http://shura.shu.ac.uk/id/eprint/10495  2006
# 4    https://www.torrossa.com/gs/resourceProxy?an=5...    -1
# ..                                                 ...   ...
# 994  https://books.google.com/books?hl=zh-CN&lr=&id...  2021
# 995  https://www.tandfonline.com/doi/abs/10.1080/14...  2013
# 996  https://onlinelibrary.wiley.com/doi/abs/10.100...  2009
# 997  https://dspace.unijos.edu.ng/jspui/bitstream/1...  2013
# 998  https://ruor.uottawa.ca/items/0cebd597-ce36-4f...  2016
#
#                                              title_new  \
# 0    aid sinoafrican relations analysis promptings ...
# 1                    competing truths northern ireland
# 2                                  protests st century
# 3    tracing fragments visual culture anticolonial ...
# 4    cultural accommodation selftranslation work la...
# ..                                                 ...
# 994  love revolution twentiethcentury colonial post...
# 995  nationalism anticolonialism crystallisation gr...
# 996                                      narchism ndia
# 997     politics accessing leadership nigerian context
# 998  dispensability new transportation technologies...
#
#                                       title_new_tokens
# 0    [aid, sinoafrican, relations, analysis, prompt...
# 1               [competing, truths, northern, ireland]
# 2                              [protests, st, century]
# 3    [tracing, fragments, visual, culture, anticolo...
# 4    [cultural, accommodation, selftranslation, wor...
# ..                                                 ...
# 994  [love, revolution, twentiethcentury, colonial,...
# 995  [nationalism, anticolonialism, crystallisation...
# 996                                   [narchism, ndia]
# 997  [politics, accessing, leadership, nigerian, co...
# 998  [dispensability, new, transportation, technolo...
#
# [999 rows x 5 columns]

# %%
from gensim.test.utils import common_texts
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
corpus = df['title_new_tokens']
for document in corpus[:5]:
    print(document)
# Out:
# ['aid', 'sinoafrican', 'relations', 'analysis', 'promptings', 'pluses', 'problems', 'chinas', 'aid', 'africa']
# ['competing', 'truths', 'northern', 'ireland']
# ['protests', 'st', 'century']
# ['tracing', 'fragments', 'visual', 'culture', 'anticolonial', 'struggle', 'britain']
# ['cultural', 'accommodation', 'selftranslation', 'work', 'layla', 'abū', 'zayd']

# %%
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    epochs = 10
)

# 保存训练好的模型
model.save('word2vec_ad.model')

# %%
word_list = model.wv.index_to_key  # 获取词汇表
word_vectors = model.wv[word_list]  # 获取词向量

# 打印词汇表和对应的词向量
for word, vector in list(zip(word_list, word_vectors))[:5]:
    print(f'{word}: {vector}')
# Out:
# anticolonial: [-4.50415118e-03  4.41437867e-03  8.48110858e-03  8.19640607e-03
#  -6.86928956e-03 -1.85482707e-02  1.03468737e-02  2.30163746e-02
#  -1.00162383e-02 -7.20318966e-03  7.81316496e-03 -1.09035987e-02
#  -4.75474726e-03  1.27899172e-02 -3.36656440e-03 -7.34231761e-03
#   5.62511664e-03 -8.22722726e-03 -8.20942130e-03 -2.16145348e-02
#   1.09595871e-02  8.41905270e-03  1.23628424e-02 -1.08531804e-03
#   5.85071836e-03 -4.00541956e-03 -4.11063200e-03  2.17326335e-03
#  -1.46571798e-02 -3.87413148e-03  5.36037434e-04 -2.05903125e-04
#   1.08726313e-02 -1.28173502e-02 -3.33022792e-03  3.15742008e-03
#   1.05367638e-02 -1.01778693e-02 -3.48807499e-03 -1.51716163e-02
#  -8.17194209e-03 -3.33108583e-05 -1.21142585e-02 -3.15601588e-03
#   6.02649059e-03 -1.15070737e-03 -1.26184477e-02  1.17472867e-02
#   8.60922690e-03  1.49707794e-02 -8.13060813e-03 -1.00477692e-03
#  -7.37288035e-03 -1.39675755e-03  4.90807323e-03  1.33168022e-03
#   7.49643892e-03 -8.59601423e-03 -9.82536469e-03  1.07285054e-02
#  -3.60781880e-04  1.93334743e-03 -5.54709369e-03 -4.96397074e-03
#  -9.63754300e-03  8.24942533e-03 -1.22671225e-03  8.91354866e-03
#  -1.00449361e-02  8.83153174e-03  2.15215213e-03  1.25651602e-02
#   4.99707274e-03 -1.14235375e-02  1.17620956e-02  3.96732986e-03
#   9.29469895e-03 -1.92653365e-03 -8.04312062e-03 -5.57372672e-03
#  -0.00452531  0.00113033 -0.0020663   0.00202095 -0.01681549 -0.00023963
#   0.01477955  0.00187249  0.00121377 -0.01441722  0.00704832 -0.00077431
#  -0.00189269 -0.00136999 -0.00358819 -0.00911284  0.00319753 -0.01272482
#  -0.01422598  0.01140099  0.01169441 -0.00921201 -0.00117604  0.00132849
#   0.00720828 -0.00263568  0.0057048  -0.00152073  0.00746399 -0.00746662
#  -0.00553958 -0.00220943 -0.00738814 -0.01061682 -0.00718696 -0.00564127
#   0.00706233 -0.0049555   0.00205328  0.00221658 -0.01168057  0.00505372
#   0.01011304  0.01452184 -0.01258949  0.01498886 -0.0091245   0.01087903
#   0.00372145  0.00173039  0.00936851  0.01177322 -0.00159216  0.00916478
#   0.00129026 -0.00606764 -0.01326606 -0.00990586 -0.00209086  0.00766115
#  -0.0078719  -0.00766377  0.00987876  0.00833337 -0.00123543 -0.00354252
#   0.00951617 -0.00252349  0.00680734 -0.0028321   0.01359401 -0.00123274
#   0.01035277 -0.00256671  0.00237952  0.0020548 ]

# %%
print(model.wv.similarity('anticolonial', 'struggle'))
print(model.wv.similarity('anticolonial', 'africa'))
print(model.wv.similarity('anticolonial', 'competing'))
print(model.wv.similarity('struggle', 'africa'))
print(model.wv.similarity('struggle', 'competing'))
print(model.wv.similarity('africa', 'competing'))
# Out:
# 0.5240608
# 0.47315645
# 0.029266924
# 0.44942653
# 0.20898442
# 0.05340431

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA #用于降维处理
import matplotlib

# 可视化

words = ['anticolonial', 'struggle', 'africa', 'competing']
vectors = [model.wv[word] for word in words]

from matplotlib.font_manager import FontProperties
font_path = '/System/Library/Fonts/PingFang.ttc' 
custom_font = FontProperties(fname=font_path, size=14)

matplotlib.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# 使用PCA进行降维
pca = PCA(n_components = 2)
pca_result = pca.fit_transform(vectors)

plt.figure()

# 取PCA降维结果中所有行的第一列和第二列数据绘制散点图，设置点的大小为50
plt.scatter(pca_result[:, 0], pca_result[:, 1], s = 50)

for i, word in enumerate(words):
    plt.annotate(word, (pca_result[i, 0], pca_result[i, 1]), fontsize = 20)

plt.xlabel('PCA维度1', fontsize = 20)
plt.ylabel('PCA维度2', fontsize = 20)
plt.title('二维语义空间中词语的分布', fontsize = 20)
plt.grid(True)
plt.show()

# %%
from gensim.models.callbacks import CallbackAny2Vec

class callback(CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 0
        self.loss_to_be_subed = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        loss_now = loss - self.loss_to_be_subed
        self.loss_to_be_subed = loss
        print('Loss after epoch {}: {}'.format(self.epoch, loss_now))
        self.epoch += 1
        
# 自己训练词嵌入模型
from gensim.models import Word2Vec

# 训练词嵌入模型
model = Word2Vec(
    corpus,     # 训练预料
    window = 5,     # 训练算法考虑的当前词语与预测词语在一个句子中的最大距离（窗口大小）
    vector_size = 100,     # 自定义训练向量维度
    min_count = 1,     # 忽略所有总频数低于这个值的词语
    compute_loss=True, callbacks=[callback()],
    epochs = 50
)

# 保存训练好的模型
model.save('word2vec_ad.model')
