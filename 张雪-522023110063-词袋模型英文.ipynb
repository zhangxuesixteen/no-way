# %% [markdown]
# # 一、 课堂代码复刻

# %% [markdown]
# # 词袋模型

# %% [markdown]
# 词袋模型（Bag of Words，简称 BoW）是自然语言处理（NLP）中常用的文本表示方法，它将文本转化为数值特征（向量），进而可以用于机器学习等高阶处理。词袋模型将语料转化为二维矩阵，横向为所有在训练数据中出现的不重复的词汇（word），纵向为语料各句子或文档（document）。
#
# 简单来说，词袋模型可以帮助大家计算词频。

# %%
# 导入数据
import pandas as pd
text_ana = pd.read_csv('text_analysis_twitter.csv')
text_ana = text_ana.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ## 数据预处理

# %%
import re

def preprocess_text(text):    
    # 转换为小写
    text = text.lower()   
    # 移除URL
    text = re.sub(r'http\S+', '', text)    
    return text

# %% [markdown]
# ## 构建词袋模型

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 初始化CountVectorizer
vectorizer = CountVectorizer()

# 将文本数据转换为词袋特征矩阵
X = vectorizer.fit_transform(text_ana["text"].apply(preprocess_text))

# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)

# 展示词袋模型中的所有特征词
print('特征词列表:', vectorizer.get_feature_names_out())
# Out:
# 词袋特征矩阵的形状: (300000, 121376)
# 特征词列表: ['00' '000' '0000' ... '투표하십시오' '한국어' 'ﬂees']

# %%
list(X.toarray())

# %% [markdown]
# ## 词频统计

# %%
# 获取词汇表
feature_words = vectorizer.get_feature_names_out()

# 计算词频统计
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))

# %%
# 观察词袋模型的词频计数结果
sorted (word_freq.items(), key=lambda x: x[1], reverse=True)

# %% [markdown]
# ## 词云图

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

# 根据词袋模型分析结果绘制词云图
wc = WordCloud(
    width=1200, 
    height=800, 
    background_color='white', 
    ).generate_from_frequencies(word_freq)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
plt.savefig('wordcloud_twi.png', dpi=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       2 import matplotlib.pyplot as plt
#       4 # 根据词袋模型分析结果绘制词云图
#       5 wc = WordCloud(
#       6     width=1200,
#       7     height=800,
#       8     background_color='white',
# ----> 9     ).generate_from_frequencies(word_freq)
#      11 # 显示词云图
#      12 plt.figure(figsize=(10, 5))
#
# NameError: name 'word_freq' is not defined

# %% [markdown]
# 在实际操作的过程中反复显示内核挂掉了，通过删除部分数据，从中随机抽取部分数据进行计算都没有办法进行。似乎是文件过大，电脑难以运行。

# %% [markdown]
# # 二、 词袋模型1——铁路与殖民统治

# %%
import pandas as pd
# 导入数据
df = pd.read_excel('railway_construction_AND_colonial_power.xlsx', header=0)  
text_column = 'title'
# 检查是否有缺失值
print(df[text_column].isnull().sum())

# 清除包含缺失值的行
df = df.dropna(subset=[text_column])

# 或者填充缺失值为空字符串
# df[text_column].fillna('', inplace=True)
# Out:
# 1

# %%
import re
def preprocess_text(text):
    # 将文本转换为小写
    text = text.lower()
    # 使用正则表达式移除URL
    text = re.sub(r'http\S+', '', text)
    return text

# %%
from sklearn.feature_extraction.text import CountVectorizer
# 初始化CountVectorizer
vectorizer = CountVectorizer()

# 将文本数据转换为词袋特征矩阵
X = vectorizer.fit_transform(df[text_column])

# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)

# 展示词袋模型中的所有特征词
feature_names = vectorizer.get_feature_names_out()
print('词汇表:', feature_names)
# Out:
# 词袋特征矩阵的形状: (999, 3023)
# 词汇表: ['0311' '04' '0995' ... '韓末' '정부관료및언론의철도에대한인식과수용' '한말']

# %%
list(X.toarray())
# Out:
# [array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 1, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 1, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 1, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 1, 1, 1]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0])]

# %% [markdown]
# ## 词频统计

# %%
# 获取词汇表
feature_words = vectorizer.get_feature_names_out()

# 计算词频统计
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))

# %%
# 观察词袋模型的词频计数结果
sorted (word_freq.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('the', 917),
#  ('and', 666),
#  ('of', 613),
#  ('in', 602),
#  ('colonial', 205),
#  ('africa', 144),
#  ('to', 87),
#  ('african', 72),
#  ('on', 70),
#  ('history', 69),
#  ('development', 65),
#  ('british', 63),
#  ('state', 55),
#  ('colonialism', 54),
#  ('empire', 52),
#  ('railway', 52),
#  ('china', 49),
#  ('from', 49),
#  ('world', 49),
#  ('economic', 48),
#  ('india', 48),
#  ('century', 47),
#  ('german', 47),
#  ('by', 45),
#  ('south', 44),
#  ('war', 42),
#  ('for', 39),
#  ('political', 39),
#  ('an', 38),
#  ('nigeria', 37),
#  ('chinese', 36),
#  ('east', 34),
#  ('historical', 34),
#  ('politics', 33),
#  ('case', 32),
#  ('kenya', 32),
#  ('study', 32),
#  ('social', 29),
#  ('as', 28),
#  ('french', 28),
#  ('asia', 27),
#  ('imperialism', 27),
#  ('west', 27),
#  ('economy', 26),
#  ('1914', 25),
#  ('labour', 24),
#  ('making', 24),
#  ('railways', 24),
#  ('early', 23),
#  ('labor', 23),
#  ('new', 23),
#  ('1900', 21),
#  ('central', 21),
#  ('imperial', 21),
#  ('indian', 21),
#  ('infrastructure', 21),
#  ('modern', 21),
#  ('nineteenth', 21),
#  ('japanese', 20),
#  ('power', 20),
#  ('rule', 20),
#  ('nation', 19),
#  ('1930', 18),
#  ('change', 18),
#  ('international', 18),
#  ('city', 17),
#  ('during', 17),
#  ('ghana', 17),
#  ('twentieth', 17),
#  ('urban', 17),
#  ('building', 16),
#  ('transport', 16),
#  ('with', 16),
#  ('between', 15),
#  ('first', 15),
#  ('its', 15),
#  ('or', 15),
#  ('post', 15),
#  ('technology', 15),
#  ('at', 14),
#  ('culture', 14),
#  ('identity', 14),
#  ('impact', 14),
#  ('national', 14),
#  ('nationalism', 14),
#  ('north', 14),
#  ('policy', 14),
#  ('resistance', 14),
#  ('1960', 13),
#  ('britain', 13),
#  ('construction', 13),
#  ('global', 13),
#  ('migration', 13),
#  ('mozambique', 13),
#  ('perspective', 13),
#  ('relations', 13),
#  ('road', 13),
#  ('struggle', 13),
#  ('tanzania', 13),
#  ('town', 13),
#  ('western', 13),
#  ('work', 13),
#  ('1940', 12),
#  ('business', 12),
#  ('edited', 12),
#  ('health', 12),
#  ('indigenous', 12),
#  ('japan', 12),
#  ('land', 12),
#  ('settler', 12),
#  ('capitalism', 11),
#  ('congo', 11),
#  ('how', 11),
#  ('introduction', 11),
#  ('middle', 11),
#  ('postcolonial', 11),
#  ('trade', 11),
#  ('women', 11),
#  ('1890', 10),
#  ('1919', 10),
#  ('america', 10),
#  ('class', 10),
#  ('coast', 10),
#  ('context', 10),
#  ('european', 10),
#  ('foreign', 10),
#  ('heritage', 10),
#  ('life', 10),
#  ('mobility', 10),
#  ('modernity', 10),
#  ('namibia', 10),
#  ('northern', 10),
#  ('public', 10),
#  ('society', 10),
#  ('system', 10),
#  ('transportation', 10),
#  ('1850', 9),
#  ('1880', 9),
#  ('1918', 9),
#  ('1920', 9),
#  ('angola', 9),
#  ('asian', 9),
#  ('before', 9),
#  ('canadian', 9),
#  ('challenges', 9),
#  ('comparative', 9),
#  ('environment', 9),
#  ('forced', 9),
#  ('formation', 9),
#  ('government', 9),
#  ('human', 9),
#  ('late', 9),
#  ('law', 9),
#  ('long', 9),
#  ('oxford', 9),
#  ('past', 9),
#  ('policies', 9),
#  ('pp', 9),
#  ('progress', 9),
#  ('science', 9),
#  ('towards', 9),
#  ('violence', 9),
#  ('1870', 8),
#  ('1896', 8),
#  ('1898', 8),
#  ('1945', 8),
#  ('age', 8),
#  ('analysis', 8),
#  ('canada', 8),
#  ('experience', 8),
#  ('france', 8),
#  ('independence', 8),
#  ('legacy', 8),
#  ('race', 8),
#  ('role', 8),
#  ('rural', 8),
#  ('russian', 8),
#  ('southern', 8),
#  ('space', 8),
#  ('spatial', 8),
#  ('their', 8),
#  ('workers', 8),
#  ('1895', 7),
#  ('1970', 7),
#  ('2002', 7),
#  ('architecture', 7),
#  ('australia', 7),
#  ('beyond', 7),
#  ('border', 7),
#  ('cambridge', 7),
#  ('cameroon', 7),
#  ('capital', 7),
#  ('company', 7),
#  ('crisis', 7),
#  ('cultural', 7),
#  ('era', 7),
#  ('food', 7),
#  ('investment', 7),
#  ('is', 7),
#  ('literature', 7),
#  ('local', 7),
#  ('non', 7),
#  ('order', 7),
#  ('origins', 7),
#  ('ottoman', 7),
#  ('people', 7),
#  ('port', 7),
#  ('portuguese', 7),
#  ('press', 7),
#  ('revolution', 7),
#  ('since', 7),
#  ('states', 7),
#  ('us', 7),
#  ('1950', 6),
#  ('19th', 6),
#  ('agriculture', 6),
#  ('changing', 6),
#  ('colonies', 6),
#  ('de', 6),
#  ('decolonization', 6),
#  ('diaspora', 6),
#  ('ecology', 6),
#  ('ethnic', 6),
#  ('europe', 6),
#  ('evolution', 6),
#  ('germany', 6),
#  ('gold', 6),
#  ('growth', 6),
#  ('hong', 6),
#  ('influence', 6),
#  ('integration', 6),
#  ('kong', 6),
#  ('mau', 6),
#  ('medicine', 6),
#  ('movement', 6),
#  ('native', 6),
#  ('oil', 6),
#  ('other', 6),
#  ('pacific', 6),
#  ('perspectives', 6),
#  ('practices', 6),
#  ('project', 6),
#  ('raj', 6),
#  ('religious', 6),
#  ('rise', 6),
#  ('saharan', 6),
#  ('silk', 6),
#  ('time', 6),
#  ('transformation', 6),
#  ('transition', 6),
#  ('under', 6),
#  ('united', 6),
#  ('writing', 6),
#  ('years', 6),
#  ('1800', 5),
#  ('1840', 5),
#  ('1860', 5),
#  ('1884', 5),
#  ('1905', 5),
#  ('1911', 5),
#  ('2000', 5),
#  ('activism', 5),
#  ('after', 5),
#  ('among', 5),
#  ('approach', 5),
#  ('belgian', 5),
#  ('black', 5),
#  ('capacity', 5),
#  ('citizenship', 5),
#  ('colony', 5),
#  ('columbia', 5),
#  ('community', 5),
#  ('conflict', 5),
#  ('contemporary', 5),
#  ('countries', 5),
#  ('country', 5),
#  ('critical', 5),
#  ('cuba', 5),
#  ('death', 5),
#  ('discourse', 5),
#  ('district', 5),
#  ('eastern', 5),
#  ('education', 5),
#  ('emergence', 5),
#  ('engagement', 5),
#  ('engineering', 5),
#  ('english', 5),
#  ('enterprise', 5),
#  ('environmental', 5),
#  ('ethiopia', 5),
#  ('finance', 5),
#  ('financial', 5),
#  ('future', 5),
#  ('gender', 5),
#  ('great', 5),
#  ('histories', 5),
#  ('ideology', 5),
#  ('indians', 5),
#  ('indonesia', 5),
#  ('industrial', 5),
#  ('infrastructural', 5),
#  ('interests', 5),
#  ('investments', 5),
#  ('iron', 5),
#  ('knowledge', 5),
#  ('korea', 5),
#  ('korean', 5),
#  ('latin', 5),
#  ('lessons', 5),
#  ('lines', 5),
#  ('malaya', 5),
#  ('meiji', 5),
#  ('military', 5),
#  ('mining', 5),
#  ('nairobi', 5),
#  ('narratives', 5),
#  ('nations', 5),
#  ('no', 5),
#  ('patterns', 5),
#  ('periphery', 5),
#  ('place', 5),
#  ('population', 5),
#  ('pre', 5),
#  ('present', 5),
#  ('process', 5),
#  ('punjab', 5),
#  ('railroad', 5),
#  ('railroads', 5),
#  ('re', 5),
#  ('regional', 5),
#  ('relationship', 5),
#  ('representations', 5),
#  ('rethinking', 5),
#  ('review', 5),
#  ('rights', 5),
#  ('security', 5),
#  ('senegal', 5),
#  ('studies', 5),
#  ('sub', 5),
#  ('sustainability', 5),
#  ('technological', 5),
#  ('theory', 5),
#  ('three', 5),
#  ('uganda', 5),
#  ('underdevelopment', 5),
#  ('understanding', 5),
#  ('university', 5),
#  ('urbanism', 5),
#  ('white', 5),
#  ('zimbabwe', 5),
#  ('1858', 4),
#  ('1882', 4),
#  ('1897', 4),
#  ('1903', 4),
#  ('1908', 4),
#  ('1910', 4),
#  ('1939', 4),
#  ('1942', 4),
#  ('1960s', 4),
#  ('1961', 4),
#  ('1980', 4),
#  ('accounting', 4),
#  ('against', 4),
#  ('anglo', 4),
#  ('architectural', 4),
#  ('bay', 4),
#  ('belt', 4),
#  ('bengal', 4),
#  ('boundaries', 4),
#  ('burma', 4),
#  ('ca', 4),
#  ('cape', 4),
#  ('cities', 4),
#  ('civilization', 4),
#  ('control', 4),
#  ('cooperation', 4),
#  ('deforestation', 4),
#  ('democracy', 4),
#  ('division', 4),
#  ('economies', 4),
#  ('effects', 4),
#  ('elites', 4),
#  ('empires', 4),
#  ('en', 4),
#  ('encounters', 4),
#  ('end', 4),
#  ('essays', 4),
#  ('exploring', 4),
#  ('factors', 4),
#  ('falola', 4),
#  ('farmers', 4),
#  ('fiscal', 4),
#  ('forest', 4),
#  ('generation', 4),
#  ('healing', 4),
#  ('imagination', 4),
#  ('immigrants', 4),
#  ('implications', 4),
#  ('infrastructures', 4),
#  ('interwar', 4),
#  ('james', 4),
#  ('landscapes', 4),
#  ('legacies', 4),
#  ('line', 4),
#  ('manchuria', 4),
#  ('memories', 4),
#  ('mexico', 4),
#  ('migrant', 4),
#  ('museums', 4),
#  ('my', 4),
#  ('natal', 4),
#  ('nature', 4),
#  ('neo', 4),
#  ('network', 4),
#  ('nigerian', 4),
#  ('northeast', 4),
#  ('not', 4),
#  ('pakistan', 4),
#  ('participation', 4),
#  ('perceptions', 4),
#  ('powers', 4),
#  ('presence', 4),
#  ('production', 4),
#  ('protest', 4),
#  ('rail', 4),
#  ('realities', 4),
#  ('reality', 4),
#  ('recruitment', 4),
#  ('region', 4),
#  ('representation', 4),
#  ('republic', 4),
#  ('research', 4),
#  ('revisiting', 4),
#  ('roads', 4),
#  ('sahara', 4),
#  ('scholarship', 4),
#  ('sector', 4),
#  ('service', 4),
#  ('shadow', 4),
#  ('shaping', 4),
#  ('short', 4),
#  ('slavery', 4),
#  ('socio', 4),
#  ('struggles', 4),
#  ('taiwan', 4),
#  ('term', 4),
#  ('territory', 4),
#  ('third', 4),
#  ('through', 4),
#  ('toyin', 4),
#  ('transfer', 4),
#  ('travel', 4),
#  ('tropical', 4),
#  ('wars', 4),
#  ('what', 4),
#  ('working', 4),
#  ('1878', 3),
#  ('1880s', 3),
#  ('1881', 3),
#  ('1885', 3),
#  ('1893', 3),
#  ('1894', 3),
#  ('1899', 3),
#  ('1901', 3),
#  ('1902', 3),
#  ('1904', 3),
#  ('1906', 3),
#  ('1907', 3),
#  ('1912', 3),
#  ('1915', 3),
#  ('1922', 3),
#  ('1925', 3),
#  ('1932', 3),
#  ('1947', 3),
#  ('1948', 3),
#  ('1949', 3),
#  ('1962', 3),
#  ('1963', 3),
#  ('1971', 3),
#  ('1975', 3),
#  ('2003', 3),
#  ('20th', 3),
#  ('across', 3),
#  ('act', 3),
#  ('administration', 3),
#  ('africans', 3),
#  ('agency', 3),
#  ('aid', 3),
#  ('aliens', 3),
#  ('alternative', 3),
#  ('anglophone', 3),
#  ('anti', 3),
#  ('athens', 3),
#  ('authority', 3),
#  ('banking', 3),
#  ('be', 3),
#  ('belonging', 3),
#  ('bibliography', 3),
#  ('brazil', 3),
#  ('capitalist', 3),
#  ('centuries', 3),
#  ('challenge', 3),
#  ('civil', 3),
#  ('coercion', 3),
#  ('colonisation', 3),
#  ('colonization', 3),
#  ('colonized', 3),
#  ('companies', 3),
#  ('competition', 3),
#  ('conflicts', 3),
#  ('congolese', 3),
#  ('conrad', 3),
#  ('conservation', 3),
#  ('constructing', 3),
#  ('contexts', 3),
#  ('corporate', 3),
#  ('cotton', 3),
#  ('credit', 3),
#  ('cultivation', 3),
#  ('currency', 3),
#  ('currey', 3),
#  ('decline', 3),
#  ('dictionary', 3),
#  ('did', 3),
#  ('disease', 3),
#  ('dispossession', 3),
#  ('disputes', 3),
#  ('dreams', 3),
#  ('dynamics', 3),
#  ('el', 3),
#  ('enemy', 3),
#  ('engineers', 3),
#  ('epidemics', 3),
#  ('essay', 3),
#  ('expansion', 3),
#  ('factor', 3),
#  ('famine', 3),
#  ('fiction', 3),
#  ('forgotten', 3),
#  ('free', 3),
#  ('frontier', 3),
#  ('general', 3),
#  ('genocide', 3),
#  ('geopolitical', 3),
#  ('george', 3),
#  ('globalization', 3),
#  ('god', 3),
#  ('governance', 3),
#  ('guinea', 3),
#  ('gulf', 3),
#  ('harbin', 3),
#  ('hindu', 3),
#  ('hinterland', 3),
#  ('hinterlands', 3),
#  ('his', 3),
#  ('historian', 3),
#  ('ii', 3),
#  ('image', 3),
#  ('immigration', 3),
#  ('impacts', 3),
#  ('indies', 3),
#  ('indochina', 3),
#  ('industrialization', 3),
#  ('industry', 3),
#  ('informal', 3),
#  ('initiative', 3),
#  ('institutions', 3),
#  ('iran', 3),
#  ('irish', 3),
#  ('isbn', 3),
#  ('islam', 3),
#  ('islands', 3),
#  ('italian', 3),
#  ('jewish', 3),
#  ('kenyan', 3),
#  ('kibera', 3),
#  ('lake', 3),
#  ('lands', 3),
#  ('leisure', 3),
#  ('les', 3),
#  ('links', 3),
#  ('malaysia', 3),
#  ('mali', 3),
#  ('maritime', 3),
#  ('markets', 3),
#  ('medical', 3),
#  ('memory', 3),
#  ('metropolis', 3),
#  ('mid', 3),
#  ('migrants', 3),
#  ('migrations', 3),
#  ('money', 3),
#  ('more', 3),
#  ('myths', 3),
#  ('netherlands', 3),
#  ('networks', 3),
#  ('niger', 3),
#  ('one', 3),
#  ('organization', 3),
#  ('original', 3),
#  ('overseas', 3),
#  ('overview', 3),
#  ('peasant', 3),
#  ('pioneer', 3),
#  ('planning', 3),
#  ('possible', 3),
#  ('poverty', 3),
#  ('prison', 3),
#  ('projects', 3),
#  ('protectorate', 3),
#  ('question', 3),
#  ('rebellion', 3),
#  ('reflections', 3),
#  ('resource', 3),
#  ('russia', 3),
#  ('scarcity', 3),
#  ('scientific', 3),
#  ('self', 3),
#  ('settlers', 3),
#  ('singapore', 3),
#  ('slave', 3),
#  ('small', 3),
#  ('sources', 3),
#  ('southeast', 3),
#  ('southwest', 3),
#  ('spaces', 3),
#  ('strategies', 3),
#  ('strategy', 3),
#  ('structure', 3),
#  ('sudan', 3),
#  ('technopolitics', 3),
#  ('tensions', 3),
#  ('thai', 3),
#  ('tourism', 3),
#  ('tracing', 3),
#  ('tracks', 3),
#  ('transnational', 3),
#  ('victorian', 3),
#  ('visions', 3),
#  ('visual', 3),
#  ('voices', 3),
#  ('volume', 3),
#  ('warfare', 3),
#  ('water', 3),
#  ('way', 3),
#  ('we', 3),
#  ('whiteness', 3),
#  ('why', 3),
#  ('win', 3),
#  ('xix', 3),
#  ('xx', 3),
#  ('04', 2),
#  ('12', 2),
#  ('1845', 2),
#  ('1855', 2),
#  ('1872', 2),
#  ('1875', 2),
#  ('1876', 2),
#  ('1879', 2),
#  ('1888', 2),
#  ('1892', 2),
#  ('1900s', 2),
#  ('1909', 2),
#  ('1910s', 2),
#  ('1916', 2),
#  ('1930s', 2),
#  ('1946', 2),
#  ('1956', 2),
#  ('1965', 2),
#  ('1976', 2),
#  ('1978', 2),
#  ('2015', 2),
#  ('2019', 2),
#  ('45', 2),
#  ('84', 2),
#  ('95', 2),
#  ('aboriginal', 2),
#  ('accounts', 2),
#  ('adibo', 2),
#  ('affairs', 2),
#  ('agricultural', 2),
#  ('ahmad', 2),
#  ('albert', 2),
#  ('alcohol', 2),
#  ('aldershot', 2),
#  ('algeria', 2),
#  ('amalgamation', 2),
#  ('american', 2),
#  ('americas', 2),
#  ('andrew', 2),
#  ('any', 2),
#  ('apartheid', 2),
#  ('appropriation', 2),
#  ('arab', 2),
#  ('architects', 2),
#  ('architectures', 2),
#  ('archive', 2),
#  ('area', 2),
#  ('argentina', 2),
#  ('arms', 2),
#  ('artistic', 2),
#  ('ashgate', 2),
#  ('aspects', 2),
#  ('assistance', 2),
#  ('austria', 2),
#  ('austro', 2),
#  ('banff', 2),
#  ('being', 2),
#  ('belgium', 2),
#  ('bioscoop', 2),
#  ('blood', 2),
#  ('bodies', 2),
#  ('bombay', 2),
#  ('borders', 2),
#  ('botswana', 2),
#  ('bourgeoisie', 2),
#  ('brazzaville', 2),
#  ('bri', 2),
#  ('buganda', 2),
#  ('built', 2),
#  ('burmese', 2),
#  ('can', 2),
#  ('capitals', 2),
#  ('causes', 2),
#  ('challenging', 2),
#  ('changes', 2),
#  ('chapter', 2),
#  ('choice', 2),
#  ('christianity', 2),
#  ('church', 2),
#  ('cinema', 2),
#  ('civilizing', 2),
#  ('clan', 2),
#  ('classes', 2),
#  ('co', 2),
#  ('coal', 2),
#  ('cold', 2),
#  ('colonizing', 2),
#  ('commercial', 2),
#  ('commonwealth', 2),
#  ('communications', 2),
#  ('compared', 2),
#  ('conditions', 2),
#  ('confluence', 2),
#  ('conquest', 2),
#  ('consequences', 2),
#  ('consumption', 2),
#  ('contender', 2),
#  ('contested', 2),
#  ('contract', 2),
#  ('contribution', 2),
#  ('contributions', 2),
#  ('convention', 2),
#  ('conversion', 2),
#  ('cosmopolitanism', 2),
#  ('creation', 2),
#  ('creative', 2),
#  ('crime', 2),
#  ('crises', 2),
#  ('curse', 2),
#  ('dakar', 2),
#  ('dark', 2),
#  ('david', 2),
#  ('debt', 2),
#  ('decolonizing', 2),
#  ('degeneracy', 2),
#  ('delta', 2),
#  ('democratic', 2),
#  ('demographic', 2),
#  ('demonstrations', 2),
#  ('dependency', 2),
#  ('design', 2),
#  ('designs', 2),
#  ('destruction', 2),
#  ('developing', 2),
#  ('dimension', 2),
#  ('dimensions', 2),
#  ('diplomacy', 2),
#  ('direct', 2),
#  ('direction', 2),
#  ('disorder', 2),
#  ('display', 2),
#  ('do', 2),
#  ('doctrine', 2),
#  ('dragon', 2),
#  ('dream', 2),
#  ('du', 2),
#  ('dutch', 2),
#  ('eco', 2),
#  ('ecologies', 2),
#  ('economics', 2),
#  ('effect', 2),
#  ('elephant', 2),
#  ('elite', 2),
#  ('emerging', 2),
#  ('employment', 2),
#  ('encounter', 2),
#  ('encyclopedia', 2),
#  ('enterprises', 2),
#  ('es', 2),
#  ('essential', 2),
#  ('establishment', 2),
#  ('ethiopian', 2),
#  ('ethnicity', 2),
#  ('eu', 2),
#  ('every', 2),
#  ('evidence', 2),
#  ('examination', 2),
#  ('example', 2),
#  ('experiences', 2),
#  ('external', 2),
#  ('fall', 2),
#  ('family', 2),
#  ('fear', 2),
#  ('fifty', 2),
#  ('fights', 2),
#  ('film', 2),
#  ('financing', 2),
#  ('fire', 2),
#  ('forces', 2),
#  ('forestry', 2),
#  ('formal', 2),
#  ('foundation', 2),
#  ('framework', 2),
#  ('francophone', 2),
#  ('geographic', 2),
#  ('geographical', 2),
#  ('geography', 2),
#  ('glen', 2),
#  ('globalisation', 2),
#  ('golden', 2),
#  ('good', 2),
#  ('governmentality', 2),
#  ('grand', 2),
#  ('grey', 2),
#  ('harm', 2),
#  ('hegemony', 2),
#  ('hierarchies', 2),
#  ('hill', 2),
#  ('historicizing', 2),
#  ('historiographies', 2),
#  ('historiography', 2),
#  ('home', 2),
#  ('honor', 2),
#  ('htet', 2),
#  ('hungarian', 2),
#  ('hunting', 2),
#  ('ideas', 2),
#  ('identities', 2),
#  ('imperative', 2),
#  ('importance', 2),
#  ('inclusion', 2),
#  ('income', 2),
#  ('incorporation', 2),
#  ('independent', 2),
#  ('indirect', 2),
#  ('indo', 2),
#  ('innovation', 2),
#  ('inquiry', 2),
#  ('internationalism', 2),
#  ('into', 2),
#  ('involvement', 2),
#  ('iraq', 2),
#  ('it', 2),
#  ('java', 2),
#  ('joseph', 2),
#  ('journey', 2),
#  ('kano', 2),
#  ('katanga', 2),
#  ('king', 2),
#  ('kingdom', 2),
#  ('komedi', 2),
#  ('koreans', 2),
#  ('labourers', 2),
#  ('lagos', 2),
#  ('lahore', 2),
#  ('landscape', 2),
#  ('language', 2),
#  ('lanka', 2),
#  ('largest', 2),
#  ('leadership', 2),
#  ('legal', 2),
#  ('leiden', 2),
#  ('leone', 2),
#  ('leopold', 2),
#  ('light', 2),
#  ('limits', 2),
#  ('lineage', 2),
#  ('london', 2),
#  ('madagascar', 2),
#  ('magic', 2),
#  ('mail', 2),
#  ('maji', 2),
#  ('major', 2),
#  ('make', 2),
#  ('malawi', 2),
#  ('malay', 2),
#  ('manchurian', 2),
#  ('market', 2),
#  ('marx', 2),
#  ('massacre', 2),
#  ('matter', 2),
#  ('medieval', 2),
#  ('meets', 2),
#  ('miners', 2),
#  ('minorities', 2),
#  ('missionaries', 2),
#  ('missions', 2),
#  ('mobilization', 2),
#  ('model', 2),
#  ('monarchy', 2),
#  ('monetary', 2),
#  ('moving', 2),
#  ('multinational', 2),
#  ('museum', 2),
#  ('name', 2),
#  ('nationalist', 2),
#  ('nationality', 2),
#  ('nationhood', 2),
#  ('natives', 2),
#  ('necessity', 2),
#  ('negotiating', 2),
#  ('neocolonialism', 2),
#  ('nh', 2),
#  ('nubis', 2),
#  ('observed', 2),
#  ('obstacles', 2),
#  ('occupied', 2),
#  ('ohio', 2),
#  ('operations', 2),
#  ('opportunity', 2),
#  ('orissa', 2),
#  ('others', 2),
#  ('our', 2),
#  ('out', 2),
#  ('ovamboland', 2),
#  ('over', 2),
#  ('palgrave', 2),
#  ('paper', 2),
#  ('park', 2),
#  ('part', 2),
#  ('pattern', 2),
#  ('paul', 2),
#  ('paving', 2),
#  ('peace', 2),
#  ('peaceful', 2),
#  ('peculiar', 2),
#  ('penal', 2),
#  ('penetration', 2),
#  ('peoples', 2),
#  ('period', 2),
#  ('pluralism', 2),
#  ('poetics', 2),
#  ('police', 2),
#  ('popular', 2),
#  ('porterage', 2),
#  ('ports', 2),
#  ('portsmouth', 2),
#  ('price', 2),
#  ('primacy', 2),
#  ('prince', 2),
#  ('privatization', 2),
#  ('problem', 2),
#  ('problems', 2),
#  ('proletariat', 2),
#  ('promise', 2),
#  ('prospects', 2),
#  ('pyongyang', 2),
#  ('qing', 2),
#  ('quest', 2),
#  ('racial', 2),
#  ('rails', 2),
#  ('rational', 2),
#  ('reading', 2),
#  ('real', 2),
#  ('recovery', 2),
#  ('reform', 2),
#  ('refugees', 2),
#  ('regimes', 2),
#  ('regulation', 2),
#  ('rhodesia', 2),
#  ('rhythms', 2),
#  ('rinderpest', 2),
#  ('rivalry', 2),
#  ('river', 2),
#  ('robinson', 2),
#  ('rochester', 2),
#  ('royal', 2),
#  ('salish', 2),
#  ('same', 2),
#  ('saving', 2),
#  ('schemes', 2),
#  ('school', 2),
#  ('schools', 2),
#  ('scientists', 2),
#  ('sembene', 2),
#  ('seoul', 2),
#  ('services', 2),
#  ('settlement', 2),
#  ('seven', 2),
#  ...]

# %% [markdown]
# ## 绘制词云图

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

# 根据词袋模型分析结果绘制词云图
wc = WordCloud(
    width=1200, 
    height=800, 
    background_color='white', 
    ).generate_from_frequencies(word_freq)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
plt.savefig('wordcloud_twi.png', dpi=100)

# %% [markdown]
# # 二、 词袋模型2——铁路与反殖民斗争

# %%
import pandas as pd
# 导入数据
df = pd.read_excel('colonial_railways_OR_anti-colonial_struggle.xlsx', header=0)  
text_column = 'title'
# 检查是否有缺失值
print(df[text_column].isnull().sum())

# 清除包含缺失值的行
df = df.dropna(subset=[text_column])

# 或者填充缺失值为空字符串
# df[text_column].fillna('', inplace=True)
# Out:
# 1

# %%
import re
def preprocess_text(text):
    # 将文本转换为小写
    text = text.lower()
    # 使用正则表达式移除URL
    text = re.sub(r'http\S+', '', text)
    return text

# %%
from sklearn.feature_extraction.text import CountVectorizer
# 初始化CountVectorizer
vectorizer = CountVectorizer()

# 将文本数据转换为词袋特征矩阵
X = vectorizer.fit_transform(df[text_column])

# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)

# 展示词袋模型中的所有特征词
feature_names = vectorizer.get_feature_names_out()
print('词汇表:', feature_names)
# Out:
# 词袋特征矩阵的形状: (998, 3310)
# 词汇表: ['00' '0374176426' '10' ... '马新独立运动' '만주액션영화의모호한민족주의' '운동과민주공화제수립의세계사적의의']

# %%
list(X.toarray())
# Out:
# [array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 1, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 1, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 1]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 1, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 1, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 1, 1, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0])]

# %% [markdown]
# ## 词频统计

# %%
# 获取词汇表
feature_words = vectorizer.get_feature_names_out()

# 计算词频统计
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))

# %%
# 观察词袋模型的词频计数结果
sorted (word_freq.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('the', 844),
#  ('and', 588),
#  ('of', 562),
#  ('in', 471),
#  ('colonial', 176),
#  ('anti', 105),
#  ('to', 98),
#  ('struggle', 80),
#  ('india', 64),
#  ('africa', 63),
#  ('from', 63),
#  ('politics', 61),
#  ('african', 57),
#  ('on', 52),
#  ('for', 48),
#  ('history', 48),
#  ('women', 47),
#  ('political', 45),
#  ('nationalism', 42),
#  ('by', 38),
#  ('new', 38),
#  ('post', 34),
#  ('railways', 34),
#  ('state', 32),
#  ('an', 31),
#  ('national', 31),
#  ('resistance', 30),
#  ('movement', 29),
#  ('war', 29),
#  ('postcolonial', 28),
#  ('south', 28),
#  ('nation', 27),
#  ('as', 26),
#  ('development', 26),
#  ('indian', 26),
#  ('violence', 25),
#  ('at', 24),
#  ('revolution', 24),
#  ('case', 22),
#  ('colonialism', 22),
#  ('memory', 22),
#  ('world', 22),
#  ('civil', 21),
#  ('social', 21),
#  ('study', 21),
#  ('fanon', 20),
#  ('contemporary', 19),
#  ('cultural', 19),
#  ('de', 19),
#  ('liberation', 19),
#  ('angola', 18),
#  ('cyprus', 18),
#  ('review', 18),
#  ('society', 18),
#  ('zimbabwe', 17),
#  ('historical', 16),
#  ('nationalist', 16),
#  ('revolutionary', 16),
#  ('singapore', 16),
#  ('between', 15),
#  ('democracy', 15),
#  ('east', 15),
#  ('gender', 15),
#  ('nigeria', 15),
#  ('palestinian', 15),
#  ('policy', 15),
#  ('we', 15),
#  ('independence', 14),
#  ('international', 14),
#  ('its', 14),
#  ('literature', 14),
#  ('pp', 14),
#  ('asia', 13),
#  ('conflict', 13),
#  ('modern', 13),
#  ('or', 13),
#  ('palestine', 13),
#  ('through', 13),
#  ('algeria', 12),
#  ('black', 12),
#  ('china', 12),
#  ('culture', 12),
#  ('democratic', 12),
#  ('education', 12),
#  ('empire', 12),
#  ('frantz', 12),
#  ('freedom', 12),
#  ('identity', 12),
#  ('movements', 12),
#  ('people', 12),
#  ('press', 12),
#  ('question', 12),
#  ('solidarity', 12),
#  ('book', 11),
#  ('community', 11),
#  ('economic', 11),
#  ('french', 11),
#  ('global', 11),
#  ('southern', 11),
#  ('towards', 11),
#  ('under', 11),
#  ('against', 10),
#  ('analysis', 10),
#  ('beyond', 10),
#  ('critical', 10),
#  ('decolonization', 10),
#  ('economy', 10),
#  ('foreign', 10),
#  ('impact', 10),
#  ('indigenous', 10),
#  ('is', 10),
#  ('life', 10),
#  ('mozambique', 10),
#  ('race', 10),
#  ('republic', 10),
#  ('role', 10),
#  ('system', 10),
#  ('university', 10),
#  ('what', 10),
#  ('with', 10),
#  ('are', 9),
#  ('century', 9),
#  ('decolonisation', 9),
#  ('feminism', 9),
#  ('imperialism', 9),
#  ('land', 9),
#  ('legacy', 9),
#  ('party', 9),
#  ('perspective', 9),
#  ('perspectives', 9),
#  ('postcolonialism', 9),
#  ('power', 9),
#  ('present', 9),
#  ('railway', 9),
#  ('reflections', 9),
#  ('rights', 9),
#  ('security', 9),
#  ('self', 9),
#  ('studies', 9),
#  ('their', 9),
#  ('united', 9),
#  ('film', 8),
#  ('introduction', 8),
#  ('islam', 8),
#  ('islamic', 8),
#  ('la', 8),
#  ('labour', 8),
#  ('language', 8),
#  ('literary', 8),
#  ('modernity', 8),
#  ('popular', 8),
#  ('soviet', 8),
#  ('terrorism', 8),
#  ('theory', 8),
#  ('two', 8),
#  ('union', 8),
#  ('us', 8),
#  ('vietnam', 8),
#  ('1960', 7),
#  ('british', 7),
#  ('building', 7),
#  ('cabral', 7),
#  ('cambridge', 7),
#  ('chinese', 7),
#  ('cinema', 7),
#  ('class', 7),
#  ('congress', 7),
#  ('counter', 7),
#  ('crisis', 7),
#  ('discourse', 7),
#  ('ethnicity', 7),
#  ('gandhi', 7),
#  ('his', 7),
#  ('identities', 7),
#  ('ideology', 7),
#  ('indonesia', 7),
#  ('into', 7),
#  ('ireland', 7),
#  ('isbn', 7),
#  ('justice', 7),
#  ('kenya', 7),
#  ('london', 7),
#  ('military', 7),
#  ('namibia', 7),
#  ('narratives', 7),
#  ('nigerian', 7),
#  ('no', 7),
#  ('our', 7),
#  ('re', 7),
#  ('reading', 7),
#  ('research', 7),
#  ('return', 7),
#  ('rule', 7),
#  ('shadow', 7),
#  ('southeast', 7),
#  ('sub', 7),
#  ('third', 7),
#  ('west', 7),
#  ('within', 7),
#  ('work', 7),
#  ('writing', 7),
#  ('1947', 6),
#  ('age', 6),
#  ('america', 6),
#  ('apartheid', 6),
#  ('arab', 6),
#  ('capitalism', 6),
#  ('caribbean', 6),
#  ('challenge', 6),
#  ('changing', 6),
#  ('da', 6),
#  ('debate', 6),
#  ('early', 6),
#  ('ethnic', 6),
#  ('example', 6),
#  ('feminist', 6),
#  ('fiction', 6),
#  ('fighting', 6),
#  ('first', 6),
#  ('frelimo', 6),
#  ('gendered', 6),
#  ('ghana', 6),
#  ('globalization', 6),
#  ('greek', 6),
#  ('how', 6),
#  ('implications', 6),
#  ('indonesian', 6),
#  ('issues', 6),
#  ('left', 6),
#  ('liberal', 6),
#  ('making', 6),
#  ('middle', 6),
#  ('muslim', 6),
#  ('non', 6),
#  ('north', 6),
#  ('not', 6),
#  ('one', 6),
#  ('pan', 6),
#  ('past', 6),
#  ('poetry', 6),
#  ('practice', 6),
#  ('remembering', 6),
#  ('rethinking', 6),
#  ('story', 6),
#  ('transnational', 6),
#  ('urban', 6),
#  ('western', 6),
#  ('where', 6),
#  ('1920', 5),
#  ('1945', 5),
#  ('activism', 5),
#  ('after', 5),
#  ('arts', 5),
#  ('asian', 5),
#  ('britain', 5),
#  ('cities', 5),
#  ('city', 5),
#  ('cold', 5),
#  ('communism', 5),
#  ('comparative', 5),
#  ('consciousness', 5),
#  ('context', 5),
#  ('critique', 5),
#  ('decolonizing', 5),
#  ('do', 5),
#  ('end', 5),
#  ('engagement', 5),
#  ('english', 5),
#  ('evolution', 5),
#  ('fall', 5),
#  ('future', 5),
#  ('guerrilla', 5),
#  ('guinea', 5),
#  ('her', 5),
#  ('hindu', 5),
#  ('historiography', 5),
#  ('human', 5),
#  ('intellectual', 5),
#  ('irish', 5),
#  ('it', 5),
#  ('knowledge', 5),
#  ('korea', 5),
#  ('lives', 5),
#  ('malabar', 5),
#  ('malaysia', 5),
#  ('marxism', 5),
#  ('nature', 5),
#  ('neo', 5),
#  ('northern', 5),
#  ('origins', 5),
#  ('peace', 5),
#  ('performance', 5),
#  ('practices', 5),
#  ('radical', 5),
#  ('rebellion', 5),
#  ('religion', 5),
#  ('revolt', 5),
#  ('right', 5),
#  ('river', 5),
#  ('road', 5),
#  ('struggles', 5),
#  ('sudan', 5),
#  ('text', 5),
#  ('that', 5),
#  ('thought', 5),
#  ('trade', 5),
#  ('tradition', 5),
#  ('transportation', 5),
#  ('turkish', 5),
#  ('turn', 5),
#  ('versus', 5),
#  ('visual', 5),
#  ('wa', 5),
#  ('york', 5),
#  ('1900', 4),
#  ('1930s', 4),
#  ('1961', 4),
#  ('1975', 4),
#  ('about', 4),
#  ('agenda', 4),
#  ('al', 4),
#  ('algerian', 4),
#  ('american', 4),
#  ('among', 4),
#  ('anticolonial', 4),
#  ('be', 4),
#  ('belonging', 4),
#  ('bengal', 4),
#  ('central', 4),
#  ('concept', 4),
#  ('conflicts', 4),
#  ('consequences', 4),
#  ('construction', 4),
#  ('contested', 4),
#  ('cuba', 4),
#  ('cypriot', 4),
#  ('defense', 4),
#  ('el', 4),
#  ('elite', 4),
#  ('europe', 4),
#  ('evidence', 4),
#  ('exploring', 4),
#  ('fertility', 4),
#  ('france', 4),
#  ('friendship', 4),
#  ('german', 4),
#  ('home', 4),
#  ('humanism', 4),
#  ('image', 4),
#  ('imperial', 4),
#  ('influence', 4),
#  ('internationalism', 4),
#  ('intervention', 4),
#  ('israeli', 4),
#  ('issue', 4),
#  ('jewish', 4),
#  ('korean', 4),
#  ('late', 4),
#  ('law', 4),
#  ('linguistic', 4),
#  ('love', 4),
#  ('mau', 4),
#  ('may', 4),
#  ('media', 4),
#  ('memories', 4),
#  ('music', 4),
#  ('muslims', 4),
#  ('myth', 4),
#  ('nationalisms', 4),
#  ('nations', 4),
#  ('nelson', 4),
#  ('networks', 4),
#  ('ngugi', 4),
#  ('novels', 4),
#  ('order', 4),
#  ('prison', 4),
#  ('process', 4),
#  ('protest', 4),
#  ('public', 4),
#  ('racism', 4),
#  ('red', 4),
#  ('refugee', 4),
#  ('religious', 4),
#  ('russian', 4),
#  ('saharan', 4),
#  ('settler', 4),
#  ('shifting', 4),
#  ('side', 4),
#  ('socialist', 4),
#  ('some', 4),
#  ('strategies', 4),
#  ('tamil', 4),
#  ('tanzania', 4),
#  ('thinking', 4),
#  ('thiong', 4),
#  ('time', 4),
#  ('timor', 4),
#  ('toward', 4),
#  ('transformation', 4),
#  ('translation', 4),
#  ('tunisia', 4),
#  ('understanding', 4),
#  ('unionism', 4),
#  ('view', 4),
#  ('visions', 4),
#  ('was', 4),
#  ('who', 4),
#  ('woman', 4),
#  ('working', 4),
#  ('zimbabwean', 4),
#  ('00', 3),
#  ('10', 3),
#  ('1850', 3),
#  ('1890', 3),
#  ('1917', 3),
#  ('1919', 3),
#  ('1930', 3),
#  ('1937', 3),
#  ('1940', 3),
#  ('1940s', 3),
#  ('1948', 3),
#  ('1950', 3),
#  ('1950s', 3),
#  ('1988', 3),
#  ('1990', 3),
#  ('27', 3),
#  ('africanism', 3),
#  ('agency', 3),
#  ('agriculture', 3),
#  ('aid', 3),
#  ('all', 3),
#  ('alternative', 3),
#  ('ambedkar', 3),
#  ('angolan', 3),
#  ('anthropological', 3),
#  ('approach', 3),
#  ('armed', 3),
#  ('au', 3),
#  ('bandung', 3),
#  ('becoming', 3),
#  ('biography', 3),
#  ('bolivia', 3),
#  ('bombay', 3),
#  ('business', 3),
#  ('canada', 3),
#  ('cape', 3),
#  ('captive', 3),
#  ('causes', 3),
#  ('change', 3),
#  ('chapter', 3),
#  ('christianity', 3),
#  ('clinic', 3),
#  ('co', 3),
#  ('collective', 3),
#  ('communication', 3),
#  ('communist', 3),
#  ('communists', 3),
#  ('conference', 3),
#  ('contradictions', 3),
#  ('cooperation', 3),
#  ('countries', 3),
#  ('dalits', 3),
#  ('decolonial', 3),
#  ('defeat', 3),
#  ('defence', 3),
#  ('delhi', 3),
#  ('diaspora', 3),
#  ('domestic', 3),
#  ('down', 3),
#  ('dr', 3),
#  ('drama', 3),
#  ('dream', 3),
#  ('during', 3),
#  ('dynamics', 3),
#  ('egypt', 3),
#  ('emancipation', 3),
#  ('era', 3),
#  ('et', 3),
#  ('european', 3),
#  ('experience', 3),
#  ('experiences', 3),
#  ('far', 3),
#  ('football', 3),
#  ('forces', 3),
#  ('formation', 3),
#  ('fundamentalism', 3),
#  ('globalized', 3),
#  ('god', 3),
#  ('guyana', 3),
#  ('hindi', 3),
#  ('house', 3),
#  ('hunger', 3),
#  ('icon', 3),
#  ('imagining', 3),
#  ('independent', 3),
#  ('indochina', 3),
#  ('infrastructure', 3),
#  ('israel', 3),
#  ('italian', 3),
#  ('japanese', 3),
#  ('java', 3),
#  ('joseph', 3),
#  ('joshua', 3),
#  ('kashmir', 3),
#  ('kerala', 3),
#  ('landscape', 3),
#  ('lanka', 3),
#  ('leadership', 3),
#  ('lessons', 3),
#  ('limits', 3),
#  ('local', 3),
#  ('long', 3),
#  ('made', 3),
#  ('malayan', 3),
#  ('man', 3),
#  ('mandela', 3),
#  ('many', 3),
#  ('maoist', 3),
#  ('masculinities', 3),
#  ('michael', 3),
#  ('mobilization', 3),
#  ('moment', 3),
#  ('mother', 3),
#  ('mugabe', 3),
#  ('myanmar', 3),
#  ('nadu', 3),
#  ('name', 3),
#  ('nehru', 3),
#  ('nkomo', 3),
#  ('notes', 3),
#  ('operation', 3),
#  ('other', 3),
#  ('overlooked', 3),
#  ('pakistan', 3),
#  ('partition', 3),
#  ('partnership', 3),
#  ('philippines', 3),
#  ('philosophy', 3),
#  ('planning', 3),
#  ('portuguese', 3),
#  ('positive', 3),
#  ('postcoloniality', 3),
#  ('pre', 3),
#  ('presence', 3),
#  ('princeton', 3),
#  ('problem', 3),
#  ('problems', 3),
#  ('progressive', 3),
#  ('propaganda', 3),
#  ('prospects', 3),
#  ('queer', 3),
#  ('questions', 3),
#  ('railroads', 3),
#  ('relations', 3),
#  ('representations', 3),
#  ('reproduction', 3),
#  ('resilience', 3),
#  ('rise', 3),
#  ('royal', 3),
#  ('said', 3),
#  ('sartre', 3),
#  ('saudi', 3),
#  ('sayyid', 3),
#  ('sea', 3),
#  ('short', 3),
#  ('significance', 3),
#  ('since', 3),
#  ('sites', 3),
#  ('socialism', 3),
#  ('speak', 3),
#  ('speech', 3),
#  ('sri', 3),
#  ('stages', 3),
#  ('states', 3),
#  ('sustainable', 3),
#  ('swapo', 3),
#  ('ten', 3),
#  ('thailand', 3),
#  ('thomas', 3),
#  ('three', 3),
#  ('times', 3),
#  ('town', 3),
#  ('transition', 3),
#  ('transport', 3),
#  ('ummah', 3),
#  ('une', 3),
#  ('unfinished', 3),
#  ('voice', 3),
#  ('wars', 3),
#  ('whose', 3),
#  ('without', 3),
#  ('writer', 3),
#  ('years', 3),
#  ('young', 3),
#  ('youth', 3),
#  ('zambia', 3),
#  ('zealand', 3),
#  ('1900s', 2),
#  ('1901', 2),
#  ('1905', 2),
#  ('1914', 2),
#  ('1918', 2),
#  ('1933', 2),
#  ('1938', 2),
#  ('1946', 2),
#  ('1951', 2),
#  ('1952', 2),
#  ('1953', 2),
#  ('1954', 2),
#  ('1955', 2),
#  ('1957', 2),
#  ('1959', 2),
#  ('1963', 2),
#  ('1967', 2),
#  ('1974', 2),
#  ('1978', 2),
#  ('1980', 2),
#  ('1994', 2),
#  ('1997', 2),
#  ('1999', 2),
#  ('2002', 2),
#  ('2004', 2),
#  ('2010', 2),
#  ('2011', 2),
#  ('2012', 2),
#  ('2014', 2),
#  ('2018', 2),
#  ('2020', 2),
#  ('2021', 2),
#  ('20th', 2),
#  ('21st', 2),
#  ('28', 2),
#  ('29', 2),
#  ('47', 2),
#  ('50', 2),
#  ('65', 2),
#  ('978', 2),
#  ('99', 2),
#  ('abdo', 2),
#  ('aboriginal', 2),
#  ('accommodation', 2),
#  ('accumulation', 2),
#  ('aceh', 2),
#  ('across', 2),
#  ('aesthetic', 2),
#  ('africans', 2),
#  ('afro', 2),
#  ('agnes', 2),
#  ('ahmad', 2),
#  ('algiers', 2),
#  ('amílcar', 2),
#  ('andhra', 2),
#  ('angolanidade', 2),
#  ('anniversary', 2),
#  ('another', 2),
#  ('anxiety', 2),
#  ('appreciation', 2),
#  ('approaches', 2),
#  ('arabia', 2),
#  ('archive', 2),
#  ('armies', 2),
#  ('arms', 2),
#  ('artistic', 2),
#  ('australia', 2),
#  ('authentic', 2),
#  ('authoritarian', 2),
#  ('authority', 2),
#  ('bangla', 2),
#  ('based', 2),
#  ('bay', 2),
#  ('beneath', 2),
#  ('blood', 2),
#  ('board', 2),
#  ('border', 2),
#  ('boundaries', 2),
#  ('branch', 2),
#  ('burma', 2),
#  ('but', 2),
#  ('cairo', 2),
#  ('caledonia', 2),
#  ('cameroon', 2),
#  ('camp', 2),
#  ('can', 2),
#  ('caribéenne', 2),
#  ('caste', 2),
#  ('centuries', 2),
#  ('challenging', 2),
#  ('chi', 2),
#  ('child', 2),
#  ('children', 2),
#  ('chosen', 2),
#  ('christian', 2),
#  ('christians', 2),
#  ('citizenship', 2),
#  ('claim', 2),
#  ('classes', 2),
#  ('collapse', 2),
#  ('colonisation', 2),
#  ('colonization', 2),
#  ('come', 2),
#  ('commitment', 2),
#  ('communities', 2),
#  ('comparison', 2),
#  ('conceptual', 2),
#  ('constitution', 2),
#  ('contextualising', 2),
#  ('contribution', 2),
#  ('contributions', 2),
#  ('control', 2),
#  ('cornell', 2),
#  ('cosmopolitanism', 2),
#  ('cost', 2),
#  ('could', 2),
#  ('counterinsurgency', 2),
#  ('country', 2),
#  ('coup', 2),
#  ('court', 2),
#  ('crime', 2),
#  ('deconstruction', 2),
#  ('detention', 2),
#  ('determinants', 2),
#  ('developmental', 2),
#  ('difference', 2),
#  ('dimension', 2),
#  ('diplomacy', 2),
#  ('disillusionment', 2),
#  ('disobedience', 2),
#  ('dispensability', 2),
#  ('doctrine', 2),
#  ('domination', 2),
#  ('du', 2),
#  ('eastern', 2),
#  ('ecowas', 2),
#  ('ed', 2),
#  ('edited', 2),
#  ('eds', 2),
#  ('effects', 2),
#  ('elections', 2),
#  ('emergence', 2),
#  ('emergent', 2),
#  ('emerging', 2),
#  ('en', 2),
#  ('energy', 2),
#  ('entangled', 2),
#  ('epistemic', 2),
#  ('est', 2),
#  ('ethiopia', 2),
#  ('eve', 2),
#  ('everyday', 2),
#  ('examining', 2),
#  ('explaining', 2),
#  ('exploration', 2),
#  ('fact', 2),
#  ('factors', 2),
#  ('family', 2),
#  ('fanonian', 2),
#  ('faultlines', 2),
#  ('fear', 2),
#  ('feet', 2),
#  ('feminisms', 2),
#  ('fences', 2),
#  ('ferment', 2),
#  ('films', 2),
#  ('finding', 2),
#  ('fire', 2),
#  ('flows', 2),
#  ('fnla', 2),
#  ('forefront', 2),
#  ('four', 2),
#  ('fragments', 2),
#  ('française', 2),
#  ('free', 2),
#  ('friends', 2),
#  ('front', 2),
#  ('gendering', 2),
#  ('genealogy', 2),
#  ('genre', 2),
#  ('geographies', 2),
#  ('geography', 2),
#  ('geopolitics', 2),
#  ('globally', 2),
#  ('go', 2),
#  ('goddesses', 2),
#  ('going', 2),
#  ('governance', 2),
#  ('gramscian', 2),
#  ('great', 2),
#  ('ground', 2),
#  ('grounds', 2),
#  ('guerillas', 2),
#  ('gukurahundi', 2),
#  ('guns', 2),
#  ('happiness', 2),
#  ('have', 2),
#  ('health', 2),
#  ('heritage', 2),
#  ('heterogeneous', 2),
#  ('high', 2),
#  ('ho', 2),
#  ('homes', 2),
#  ('hong', 2),
#  ('hybridity', 2),
#  ('hyderabad', 2),
#  ('idea', 2),
#  ('identification', 2),
#  ('ihimaera', 2),
#  ('ii', 2),
#  ('im', 2),
#  ('imagination', 2),
#  ('immigration', 2),
#  ('indies', 2),
#  ('industry', 2),
#  ('infidels', 2),
#  ('institute', 2),
#  ('insurgency', 2),
#  ('insurgent', 2),
#  ('intellectuals', 2),
#  ('inter', 2),
#  ('intercultural', 2),
#  ('interview', 2),
#  ('interwar', 2),
#  ('investment', 2),
#  ('iraqi', 2),
#  ('ithaca', 2),
#  ('jain', 2),
#  ('james', 2),
#  ('jawaharlal', 2),
#  ('jihād', 2),
#  ('jomo', 2),
#  ('kanak', 2),
#  ('kanthapura', 2),
#  ('kenyatta', 2),
#  ('key', 2),
#  ('khaled', 2),
#  ('kim', 2),
#  ('kong', 2),
#  ('kurdistan', 2),
#  ('lahore', 2),
#  ('laos', 2),
#  ('latin', 2),
#  ('leaders', 2),
#  ('legacies', 2),
#  ('les', 2),
#  ('liberalism', 2),
#  ('liberties', 2),
#  ('limitations', 2),
#  ('line', 2),
#  ('live', 2),
#  ('liverpool', 2),
#  ('locating', 2),
#  ('look', 2),
#  ('lost', 2),
#  ('luta', 2),
#  ('macmillan', 2),
#  ('madness', 2),
#  ('maghrib', 2),
#  ('management', 2),
#  ('margins', 2),
#  ('martin', 2),
#  ('marx', 2),
#  ('mass', 2),
#  ('masses', 2),
#  ('mauritius', 2),
#  ('mbeki', 2),
#  ('message', 2),
#  ('metaphor', 2),
#  ('methods', 2),
#  ('militant', 2),
#  ('millennial', 2),
#  ('minh', 2),
#  ('ministry', 2),
#  ('mirror', 2),
#  ('mixed', 2),
#  ('mobilising', 2),
#  ('mobility', 2),
#  ('mohammed', 2),
#  ('moroccan', 2),
#  ('mountain', 2),
#  ('municipal', 2),
#  ('na', 2),
#  ('nahla', 2),
#  ('nam', 2),
#  ('narration', 2),
#  ('narrative', 2),
#  ('natal', 2),
#  ('nationalised', 2),
#  ('nationhood', 2),
#  ('need', 2),
#  ('negotiating', 2),
#  ('negro', 2),
#  ('nehanda', 2),
#  ('neocolonial', 2),
#  ('neoliberal', 2),
#  ('neoliberalism', 2),
#  ('never', 2),
#  ('ngũgĩ', 2),
#  ('nine', 2),
#  ('nkrumah', 2),
#  ('note', 2),
#  ('oceans', 2),
#  ('oil', 2),
#  ('okonkwo', 2),
#  ('oral', 2),
#  ('ordinary', 2),
#  ('organizing', 2),
#  ('out', 2),
#  ('outlines', 2),
#  ('paektu', 2),
#  ('pages', 2),
#  ('palgrave', 2),
#  ('paper', 2),
#  ('paperback', 2),
#  ('paris', 2),
#  ('parties', 2),
#  ('pathways', 2),
#  ('peasant', 2),
#  ('pedagogy', 2),
#  ('pentecostalism', 2),
#  ('peoples', 2),
#  ('pepetela', 2),
#  ('perceptions', 2),
#  ('period', 2),
#  ('petition', 2),
#  ('pioneer', 2),
#  ('placing', 2),
#  ('plan', 2),
#  ('poem', 2),
#  ('poetics', 2),
#  ('politicisation', 2),
#  ('populism', 2),
#  ('postcoloniale', 2),
#  ('postcolony', 2),
#  ('praxis', 2),
#  ('prisons', 2),
#  ('private', 2),
#  ('profession', 2),
#  ('program', 2),
#  ('project', 2),
#  ('promised', 2),
#  ('provide', 2),
#  ('publishing', 2),
#  ('rain', 2),
#  ('raj', 2),
#  ('rap', 2),
#  ('real', 2),
#  ('reassessment', 2),
#  ('rebel', 2),
#  ('reclaiming', 2),
#  ('reconstruction', 2),
#  ('recovering', 2),
#  ('reform', 2),
#  ('reformation', 2),
#  ('regained', 2),
#  ('region', 2),
#  ('renamo', 2),
#  ('representation', 2),
#  ('repression', 2),
#  ('researcher', 2),
#  ('resolution', 2),
#  ('resources', 2),
#  ('revisiting', 2),
#  ('rhetoric', 2),
#  ('ritual', 2),
#  ('roots', 2),
#  ('routledge', 2),
#  ('roy', 2),
#  ('ruling', 2),
#  ('rural', 2),
#  ('sacred', 2),
#  ('sans', 2),
#  ('searching', 2),
#  ('securitization', 2),
#  ('seine', 2),
#  ('series', 2),
#  ('service', 2),
#  ('settled', 2),
#  ('shadows', 2),
#  ('shakespeare', 2),
#  ('shall', 2),
#  ('shan', 2),
#  ('silence', 2),
#  ('silences', 2),
#  ('silent', 2),
#  ('sino', 2),
#  ('slice', 2),
#  ('sobre', 2),
#  ('socio', 2),
#  ('somalis', 2),
#  ('soul', 2),
#  ('sovereignty', 2),
#  ('space', 2),
#  ('spaces', 2),
#  ('spirit', 2),
#  ('spiritual', 2),
#  ('stability', 2),
#  ('statement', 2),
#  ('stone', 2),
#  ('stories', 2),
#  ('strategic', 2),
#  ('strategy', 2),
#  ...]

# %% [markdown]
# ## 绘制词云图

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

# 根据词袋模型分析结果绘制词云图
wc = WordCloud(
    width=1200, 
    height=800, 
    background_color='white', 
    ).generate_from_frequencies(word_freq)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
plt.savefig('wordcloud_twi.png', dpi=100)
